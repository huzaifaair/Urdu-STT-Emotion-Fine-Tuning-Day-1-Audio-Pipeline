# %% [markdown]
# # Day 3: Whisper Large-v3 LoRA Fine-Tuning for Urdu STT
#
# This notebook loads the sanitized Urdu STT dataset splits (`processed/splits/stt/train.jsonl` and `val.jsonl`) and fine-tunes `openai/whisper-large-v3` using Hugging Face **PEFT (LoRA)** on Google Colab GPU (T4 / L4 / A100).

# %%
# Step 1: Install required dependencies
# !pip install -q transformers peft datasets evaluate jiwer accelerate bitsandbytes soundfile

# %%
# Step 2: Verify GPU availability
import torch
print("CUDA Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device Name:", torch.cuda.get_device_name(0))

# %%
# Step 3: Run LoRA Fine-Tuning Script
# !python pipeline/train_stt_lora.py \
    --model_name openai/whisper-large-v3 \
    --language Urdu \
    --task transcribe \
    --epochs 3 \
    --batch_size 4 \
    --grad_accum 2 \
    --learning_rate 1e-3
